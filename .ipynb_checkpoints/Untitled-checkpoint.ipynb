# %%
import despy as dp

# %%
import models.abel_baker1 as ab1

# %%
ab_model = ab1.AbelBakerModel()

# %%
sim = dp.Simulation(ab_model)

# %%
sim.initialize()

# %%
results = sim.runf()
# Out:
#    0|   0|    0-1|Event   |Arrival Timer| interval: 3| Customer: Customer:1
#    1|   0|    0-1|Msg     |Starting Service| Abel station: 0| Entity: Customer:1
#    2|   0|    2+0|Event   |Finished Service| Abel: duration: 2| Entity: Customer:1
#    3|   0|    3-1|Event   |Arrival Timer| interval: 1| Customer: Customer:2
#    4|   0|    3-1|Msg     |Starting Service| Abel station: 0| Entity: Customer:2
#    5|   0|    4-1|Event   |Arrival Timer| interval: 2| Customer: Customer:3
#    6|   0|    4-1|Msg     |Starting Service| Baker station: 0| Entity: Customer:3
#    7|   0|    5+0|Event   |Finished Service| Abel: duration: 2| Entity: Customer:2
#    8|   0|    6-1|Event   |Arrival Timer| interval: 2| Customer: Customer:4
#    9|   0|    6-1|Msg     |Starting Service| Abel station: 0| Entity: Customer:4
#   10|   0|    7+0|Event   |Finished Service| Baker: duration: 3| Entity: Customer:3
#   11|   0|    8-1|Event   |Arrival Timer| interval: 3| Customer: Customer:5
# ...
